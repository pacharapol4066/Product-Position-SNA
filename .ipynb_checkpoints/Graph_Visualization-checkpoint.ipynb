# %% [markdown]
# ### IS - PPSNA T-SNE, Robustness check and Visualization (SNA & MDS)

# %%
import operator
import numpy as np
import seaborn as sns
import pandas as pd
import scipy
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
from matplotlib import rcParams
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Tahoma']

# %%
import matplotlib.pyplot as plt
import networkx as nx

#pip install pygsp
from pygsp import graphs

# %%
import nltk
from nltk import bigrams
import collections

# %%
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer

# %%
# Files definition
comment_freq = 'output\comment_cooc_freq.xlsx'
comment_lift = 'output\comment_cooc_lift.xlsx'

# %%
brands = ['เมจิ', 'ไทยเดนมาร์ค', 'ดัชมิลล์', 'แมคโนเลีย', 'จิตรลดา', 'แดรี่โฮม',
       'โฟร์โมสต์', 'โชคชัย', 'คาเนชั่น', 'หนองโพ', 'เอ็มมิลค์', 'บีทาเก้น']

# %% [markdown]
# เปิดไฟล์ที่ได้จากขั้นตอน Data Prep

# %%
cooc_matrix_freq = pd.read_excel(comment_freq,index_col=0)
cooc_matrix_lift = pd.read_excel(comment_lift,index_col=0)

# %%
cooc_matrix_freq = cooc_matrix_freq[brands]

# %%
cooc_matrix_freq.describe().stack().unstack(0)
# Out:
#              count       mean        std  min  25%  50%   75%    max
# เมจิ         195.0  29.394872  51.097370  0.0  3.0  9.0  30.0  367.0
# ไทยเดนมาร์ค  195.0  10.769231  21.102672  0.0  0.0  2.0   8.0  139.0
# ดัชมิลล์     195.0  10.220513  18.125496  0.0  1.0  4.0  11.0  117.0
# แมคโนเลีย    195.0   0.292308   0.643518  0.0  0.0  0.0   0.0    4.0
# จิตรลดา      195.0   7.502564  15.610390  0.0  0.0  2.0   5.0   87.0
# แดรี่โฮม     195.0   2.733333   6.612287  0.0  0.0  0.0   2.0   41.0
# โฟร์โมสต์    195.0  19.569231  33.812843  0.0  1.5  6.0  21.5  245.0
# โชคชัย       195.0   4.989744  11.299115  0.0  0.0  1.0   4.0   74.0
# คาเนชั่น     195.0   0.676923   2.113587  0.0  0.0  0.0   0.0   16.0
# หนองโพ       195.0   7.789744  16.720624  0.0  0.0  1.0   5.0  104.0
# เอ็มมิลค์    195.0   0.548718   0.920240  0.0  0.0  0.0   2.0    3.0
# บีทาเก้น     195.0   0.297436   0.691438  0.0  0.0  0.0   0.0    4.0

# %% [markdown]
# สร้างกราฟ

# %%
def stackForGraph(cm):
    stack_matrix = pd.DataFrame(cm.stack())
    stack_matrix.index.names = ['item', 'relatedItem']
    stack_matrix.columns = ['coocValue']
    stack_matrix.reset_index(inplace=True)
    stack_matrix = stack_matrix[(stack_matrix.item != stack_matrix.relatedItem)]
    stack_matrix.sort_values(by='coocValue',ascending=False).head(10)
    return stack_matrix

# %%
def plot_pandas_graph(df):
    fig, ax=plt.subplots(figsize=(15,8))
    G=nx.from_pandas_edgelist(df,source='item',target='relatedItem')
    nx.draw(G,with_labels=True, font_family='Tahoma',node_color='yellow')
    plt.show()
    return G

# %%
def create_upperTriMatrix(df):
    df.values[np.tril(np.ones(df.shape)).astype(np.bool)] = 0
    return df

# %% [markdown]
# Upper matrix plot (Co-occurence without normalization)

# %%
#cooc_matrix_ = create_upperTriMatrix(cooc_matrix)
#cooc_matrix_2 = stackForGraph(cooc_matrix_)

cooc_matrix_2 = stackForGraph(cooc_matrix_lift)
cooc_matrix_2_filter = cooc_matrix_2[(cooc_matrix_2.coocValue >= 0.1)&(cooc_matrix_2.item.isin(brands))]
#cooc_matrix_2_filter = cooc_matrix_2[(cooc_matrix_2.coocValue >= 0.4)]

# %%
cooc_matrix_2
# Out:
#                 item   relatedItem  coocValue
# 1               เมจิ   ไทยเดนมาร์ค   0.049170
# 2               เมจิ      ดัชมิลล์   0.062580
# 3               เมจิ     แมคโนเลีย   0.002554
# 4               เมจิ       จิตรลดา   0.026820
# 5               เมจิ      แดรี่โฮม   0.021073
# ...              ...           ...        ...
# 38019  คุณแม่มือใหม่       ไอโอดีน   0.000000
# 38020  คุณแม่มือใหม่  พรีเซ็นเตอร์   0.000000
# 38021  คุณแม่มือใหม่         สุนัข   0.000000
# 38022  คุณแม่มือใหม่       คายทิ้ง   0.000000
# 38023  คุณแม่มือใหม่         มีลูก   0.166667
#
# [37830 rows x 3 columns]

# %%
G2 = plot_pandas_graph(cooc_matrix_2_filter)

# %%
from community import community_louvain
partition = community_louvain.best_partition(G2)

# %%
fig, ax=plt.subplots(figsize=(15,8))
G2=nx.from_pandas_edgelist(cooc_matrix_2_filter,source='item',target='relatedItem')
pos = nx.kamada_kawai_layout(G2)
nx.draw_networkx_nodes(G2,pos,partition.keys(),node_color=list(partition.values()))
nx.draw_networkx_edges(G2, pos, alpha=0.5)
nx.draw_networkx_labels(G2,pos,font_family='Tahoma')
plt.show()

# %% [markdown]
# ### MDS สำหรับตรวจผล (Matrix ต้องสมมาตร 100% : ทั้งมิติและค่า ดังนั้นจะใช้ได้แต่ค่า freq/distance)

# %%
df_mds_matrix_dist = cooc_matrix_freq[0:12]

# %%
df_mds_matrix_dist
# Out:
#              เมจิ  ไทยเดนมาร์ค  ดัชมิลล์  แมคโนเลีย  จิตรลดา  แดรี่โฮม  \
# เมจิ            0           77        98          4       42        33
# ไทยเดนมาร์ค    77            0        26          1       87        22
# ดัชมิลล์       98           26         0          1       21         5
# แมคโนเลีย       4            1         1          0        1         1
# จิตรลดา        42           87        21          1        0        11
# แดรี่โฮม       33           22         5          1       11         0
# โฟร์โมสต์     123           83        64          3       39         1
# โชคชัย         62           45        22          1       30        26
# คาเนชั่น       12            0         1          0        0         0
# หนองโพ         78          104        30          0       75        28
# เอ็มมิลค์       2            0         2          0        0         0
# บีทาเก้น        3            0         0          0        0         0
#
#              โฟร์โมสต์  โชคชัย  คาเนชั่น  หนองโพ  เอ็มมิลค์  บีทาเก้น
# เมจิ               123      62        12      78          2         3
# ไทยเดนมาร์ค         83      45         0     104          0         0
# ดัชมิลล์            64      22         1      30          2         0
# แมคโนเลีย            3       1         0       0          0         0
# จิตรลดา             39      30         0      75          0         0
# แดรี่โฮม             1      26         0      28          0         0
# โฟร์โมสต์            0      18         2      52          0         1
# โชคชัย              18       0         0      52          0         0
# คาเนชั่น             2       0         0       0          0         0
# หนองโพ              52      52         0       0          0         0
# เอ็มมิลค์            0       0         0       0          0         0
# บีทาเก้น             1       0         0       0          0         0

# %%
from sklearn.manifold import MDS

embedding = MDS(n_components=2,dissimilarity='precomputed')
mds_coord = embedding.fit_transform(df_mds_matrix_dist)
mds_coord.shape
# Out:
# (12, 2)

# %%
fig, ax=plt.subplots(figsize=(10,5))
ax.set_title('MDS Perceptual map for brand position', fontsize=20)
plt.scatter(mds_coord[:,0],mds_coord[:,1])
labels=df_mds_matrix_dist.columns
for label,x,y in zip(labels,mds_coord[:,0],mds_coord[:,1]):
    plt.annotate(label,(x,y), fontsize=13)
plt.xlabel('PC1', fontsize=16)
plt.ylabel('PC2', fontsize=16)
plt.show()
